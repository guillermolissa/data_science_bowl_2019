# %%
from feature_selector import FeatureSelector

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
import pandas as pd
import pickle as pickle
import numpy as np


# %matplotlib inline
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import warnings; warnings.simplefilter('ignore')

# %%
train = pd.read_pickle('data/features/train_features_002.pkl')

# %%
labels = pd.read_pickle('data/features/train_labels.pkl')

# %%
train.shape
# Out:
# (17690, 157)

# %%
# Features are in train and labels are in train_labels
fs = FeatureSelector(data = train, labels = labels)

# %% [markdown]
# ### Missing Values

# %%
fs.identify_missing(missing_threshold = 0.6)
# Out:
# 0 features with greater than 0.60 missing values.

# %%
fs.missing_stats.head(6)
# Out:
#                             missing_fraction
# 12 Monkeys                               0.0
# 12 Monkeys_count                         0.0
# Fireworks (Activity)_count               0.0
# Pan Balance_count                        0.0
# Scrub-A-Dub_count                        0.0
# All Star Sorting_count                   0.0

# %%
missing_features = fs.ops['missing']
missing_features[:6]
# Out:
# []

# %%
fs.plot_missing()

# %% [markdown]
# No missing values found

# %% [markdown]
# ### Collinear Features

# %%
fs.identify_collinear(correlation_threshold = 0.9)
# Out:
# 38 features with a correlation magnitude greater than 0.90.

# %%
fs.plot_collinear()

# %%
# list of collinear features to remove
collinear_features = fs.ops['collinear']# dataframe of collinear features
fs.record_collinear
# Out:
#                     drop_feature                 corr_feature  corr_value
# 0                           2080                         2050    0.971198
# 1                           2083                         2050    0.955086
# 2                           2083                         2080    0.957627
# 3                           3110                     Activity    0.941494
# 4                           3110                         Game    0.907375
# 5                           3110                         2080    0.925328
# 6                           3110                         2083    0.914568
# 7                           3120                         3110    0.903122
# 8                           3121                         2083    0.900769
# 9                           3121                         3110    0.952454
# 10                          4235                         4230    1.000000
# 11                          5010                         5000    0.999185
# 12                          4010                         Game    0.989279
# 13                          4010                         3110    0.903905
# 14                          4020                     Activity    0.926017
# 15                          4020                         3110    0.969535
# 16                          4020                         3120    0.919503
# 17                          4020                         3121    0.939898
# 18                          4025                     Activity    0.903509
# 19                          4025                         3110    0.926447
# 20                          4025                         4020    0.916074
# 21                          4030                     Activity    0.920499
# 22                          4030                         3110    0.928216
# 23                          4030                         4020    0.962835
# 24                          4030                         4025    0.913877
# 25                          3010                     Activity    0.943419
# 26                          3010                         Game    0.910429
# 27                          3010                         2080    0.925524
# 28                          3010                         2083    0.912999
# 29                          3010                         3110    0.999929
# ..                           ...                          ...         ...
# 127  accumulated_uncorrect_games                         3120    0.922951
# 128  accumulated_uncorrect_games                         4020    0.937285
# 129  accumulated_uncorrect_games                         3010    0.913068
# 130  accumulated_uncorrect_games                         3020    0.920137
# 131  accumulated_uncorrect_games                         2020    0.923373
# 132  accumulated_uncorrect_games                         2030    0.912560
# 133  accumulated_uncorrect_games               Game_eventacum    0.967514
# 134  accumulated_uncorrect_games          accumulated_actions    0.931609
# 135  accumulated_uncorrect_games    accumulated_correct_games    0.935442
# 136     accumulated_misses_games               Game_eventacum    0.920307
# 137     accumulated_misses_games  accumulated_uncorrect_games    0.954276
# 138         sum_event_code_count                     Activity    0.940365
# 139         sum_event_code_count                         Game    0.901860
# 140         sum_event_code_count                         2080    0.901927
# 141         sum_event_code_count                         3110    0.976843
# 142         sum_event_code_count                         3120    0.931666
# 143         sum_event_code_count                         3121    0.934358
# 144         sum_event_code_count                         4020    0.987748
# 145         sum_event_code_count                         4025    0.930825
# 146         sum_event_code_count                         4030    0.969351
# 147         sum_event_code_count                         3010    0.977962
# 148         sum_event_code_count                         3020    0.930458
# 149         sum_event_code_count                         3021    0.935654
# 150         sum_event_code_count                         2020    0.959048
# 151         sum_event_code_count                         2030    0.941508
# 152         sum_event_code_count           Activity_eventacum    0.916589
# 153         sum_event_code_count               Game_eventacum    0.963849
# 154         sum_event_code_count          accumulated_actions    1.000000
# 155         sum_event_code_count    accumulated_correct_games    0.920791
# 156         sum_event_code_count  accumulated_uncorrect_games    0.931609
#
# [157 rows x 3 columns]

# %% [markdown]
# ### Single Unique Value Features

# %%
fs.identify_single_unique()
# Out:
# 30 features with a single unique value.

# %%
fs.plot_unique()

# %%
fs.ops['single_unique']
# Out:
# ['12 Monkeys',
#  'Balancing Act',
#  'Bird Measurer (Assessment)',
#  'Cart Balancer (Assessment)',
#  'Chest Sorter (Assessment)',
#  'Costume Box',
#  'Crystal Caves - Level 2',
#  'Crystal Caves - Level 3',
#  'Heavy, Heavier, Heaviest',
#  'Honey Cake',
#  'Magma Peak - Level 1',
#  "Pirate's Tale",
#  'Rulers',
#  'Slop Problem',
#  'Treasure Map',
#  'Tree Top City - Level 1',
#  'Tree Top City - Level 2',
#  'Tree Top City - Level 3',
#  'Welcome to Lost Lagoon!',
#  'Cauldron Filler (Assessment)',
#  'Crystal Caves - Level 1',
#  'Lifting Heavy Things',
#  'Magma Peak - Level 2',
#  'Mushroom Sorter (Assessment)',
#  'Ordering Spheres',
#  'Bird Measurer (Assessment)_count',
#  'Cart Balancer (Assessment)_count',
#  'Chest Sorter (Assessment)_count',
#  'Mushroom Sorter (Assessment)_count',
#  'Cauldron Filler (Assessment)_count']

# %% [markdown]
# ### Removing Features

# %%
# methods: 'missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'
#train_removed = fs.remove(methods = 'all')

# %%
train_removed = fs.remove(methods = ['collinear', 'single_unique'])
# Out:
# Removed 68 features.

# %%
train_removed.shape
# Out:
# (17690, 89)

# %% [markdown]
# ### Removing Constant features

# %%
constant_filter = VarianceThreshold(threshold=0)

# %%
constant_filter.fit(train_removed) #[features].replace([np.inf, -np.inf, np.nan],0))

# %%
print(len(train_removed.columns[constant_filter.get_support()]), " features are not constant")

# %%
constant_columns = [column for column in train_removed.columns
                    if column not in train_removed.columns[constant_filter.get_support()]]

print(len(constant_columns), " features are constant")

# %%
print(constant_columns)

# %% [raw]
# # removing constant features
# train_removed = constant_filter.transform(train_removed)

# %% [markdown]
# ### Removing Quasi-Constant Features

# %%
qconstant_filter = VarianceThreshold(threshold=0.01)

# %%
qconstant_filter.fit(train_removed)
# Out:
# VarianceThreshold(threshold=0.01)

# %%
print(len(train_removed.columns[qconstant_filter.get_support()]), " features are not quasi-constant")
# Out:
# 89  features are not quasi-constant

# %%
quasiconstant_columns = [column for column in train.columns
                    if column not in train_removed.columns[qconstant_filter.get_support()]]

print(len(quasiconstant_columns), " features are quasi-constant")
# Out:
# 68  features are quasi-constant

# %%
for q in quasiconstant_columns:
    print(q)
# Out:
# 12 Monkeys
# Balancing Act
# Bird Measurer (Assessment)
# Cart Balancer (Assessment)
# Chest Sorter (Assessment)
# Costume Box
# Crystal Caves - Level 2
# Crystal Caves - Level 3
# Heavy, Heavier, Heaviest
# Honey Cake
# Magma Peak - Level 1
# Pirate's Tale
# Rulers
# Slop Problem
# Treasure Map
# Tree Top City - Level 1
# Tree Top City - Level 2
# Tree Top City - Level 3
# Welcome to Lost Lagoon!
# Cauldron Filler (Assessment)
# Crystal Caves - Level 1
# Lifting Heavy Things
# Magma Peak - Level 2
# Mushroom Sorter (Assessment)
# Ordering Spheres
# 2080
# 2083
# 3110
# 3120
# 3121
# 4235
# 5010
# 4010
# 4020
# 4025
# 4030
# 3010
# 3020
# 3021
# 2000
# 2020
# 2030
# 2035
# 2040
# Bird Measurer (Assessment)_count
# Cart Balancer (Assessment)_count
# Chest Sorter (Assessment)_count
# Tree Top City - Level 1_count
# Pirate's Tale_count
# Tree Top City - Level 3_count
# Crystal Caves - Level 2_count
# Mushroom Sorter (Assessment)_count
# Crystal Caves - Level 1_count
# Cauldron Filler (Assessment)_count
# Clip_eventacum
# Activity_eventacum
# Assessment_eventacum
# Game_eventacum
# accumulated_correct_attempts
# accumulated_uncorrect_attempts
# 0
# 3
# accumulated_accuracy_group
# accumulated_actions
# accumulated_correct_games
# accumulated_uncorrect_games
# accumulated_misses_games
# sum_event_code_count

# %% [raw]
# train = qconstant_filter.transform(train)
# test = qconstant_filter.transform(test)

# %% [markdown]
# ### Removing Duplicate Features

# %%
train_features_T = train_removed.T
train_features_T.shape
# Out:
# (89, 17690)

# %%
print("Number of features duplicate", train_features_T.duplicated().sum())
# Out:
# Number of features duplicate 0

# %%
unique_features = train_features_T.drop_duplicates(keep='first').T.columns.tolist()

# %%
unique_features[:5]
# Out:
# ['Activity',
#  'Air Show',
#  'All Star Sorting',
#  'Assessment',
#  'Bottle Filler (Activity)']

# %%
train_removed = train_removed[unique_features]

# %% [markdown]
# ### Zero Importance Features

# %%
# Pass in the appropriate parameters
fs.identify_zero_importance(task = 'classification', 
                            eval_metric = 'auc', 
                            n_iterations = 10, 
                             early_stopping = True)# list of zero importance features
zero_importance_features = fs.ops['zero_importance']
# Out:
# Training Gradient Boosting Model
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     196     try:
# --> 197         booster = Booster(params=params, train_set=train_set)
#     198         if is_valid_contain_train:
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, silent)
#    1551             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1552                 train_set.construct().handle,
#    1553                 c_str(params_str),
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in construct(self)
#    1000                                 silent=self.silent, feature_name=self.feature_name,
# -> 1001                                 categorical_feature=self.categorical_feature, params=self.params)
#    1002             if self.free_raw_data:
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     790         elif isinstance(data, np.ndarray):
# --> 791             self.__init_from_np2d(data, params_str, ref_dataset)
#     792         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#     854             ref_dataset,
# --> 855             ctypes.byref(self.handle)))
#     856         return self
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in _safe_call(ret)
#      45     if ret != 0:
# ---> 46         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      47
#
# LightGBMError: Multiclass objective and metrics don't match
#
# During handling of the above exception, another exception occurred:
#
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-111-ea98e016e812> in <module>
#       3                             eval_metric = 'auc',
#       4                             n_iterations = 10,
# ----> 5                              early_stopping = True)# list of zero importance features
#       6 zero_importance_features = fs.ops['zero_importance']
#
# ~/projects/kaggle/data_science_bowl_2019/notebooks/features/feature_selector.py in identify_zero_importance(self, task, eval_metric, n_iterations, early_stopping)
#     309                 model.fit(train_features, train_labels, eval_metric = eval_metric,
#     310                           eval_set = [(valid_features, valid_labels)],
# --> 311                           early_stopping_rounds = 100, verbose = -1)
#     312
#     313                 # Clean up memory
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     742                                         verbose=verbose, feature_name=feature_name,
#     743                                         categorical_feature=categorical_feature,
# --> 744                                         callbacks=callbacks)
#     745         return self
#     746
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     542                               verbose_eval=verbose, feature_name=feature_name,
#     543                               categorical_feature=categorical_feature,
# --> 544                               callbacks=callbacks)
#     545
#     546         if evals_result:
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     201             booster.add_valid(valid_set, name_valid_set)
#     202     finally:
# --> 203         train_set._reverse_update_params()
#     204         for valid_set in reduced_valid_sets:
#     205             valid_set._reverse_update_params()
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in _reverse_update_params(self)
#    1095         self.params_back_up = None
#    1096         if self.handle is not None and self.params is not None:
# -> 1097             _safe_call(_LIB.LGBM_DatasetUpdateParam(self.handle, c_str(param_dict_to_str(self.params))))
#    1098         return self
#    1099
#
# /opt/anaconda3/envs/xgboostenv/lib/python3.7/site-packages/lightgbm/basic.py in _safe_call(ret)
#      44     """
#      45     if ret != 0:
# ---> 46         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      47
#      48
#
# LightGBMError: Multiclass objective and metrics don't match

# %%
zero_importance_features
# Out:
# ['motivo_contacto_cod',
#  'diff_dtalta_dtcertinicio',
#  'diff_dt_alta_compra',
#  'prestacion_reemplazo_bool',
#  'prestacion_indemnizacion_bool',
#  'cobertura_dano_accidental_bool',
#  'diff_dt_certemit_compra']

# %%
# plot the feature importances
fs.plot_feature_importances(threshold = 0.99, plot_n = 12)
# Out:
# 47 features required for 0.99 of cumulative importance

# %%
np.save('data/features/features_selected.npy',train_removed.columns.tolist())
