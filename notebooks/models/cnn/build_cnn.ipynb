# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets
from torch.autograd import Variable
from barbar import Bar

# %%
from sklearn.metrics import balanced_accuracy_score

# %%
from torch.utils.data import Dataset, DataLoader

# %%
import pandas as pd
import pickle

# %%
import torch.utils.data as utils

# %%
import numpy as np

# %%
from torch.optim import lr_scheduler

# %%
DATAPATH = 'data/features/'
MODELPATH = 'output/models/'

# %% [markdown]
# ### STEP 2: LOADING DATASET

# %%
class CattleSoundDataset(Dataset):
    """ FreeSound dataset."""

    # Initialize your data, download, etc.
    def __init__(self, X, y):
        
        self.len = X.shape[0]
        self.x_data = torch.from_numpy(X)
        self.y_data = torch.from_numpy(y)

    def __getitem__(self, index):
        return (self.x_data[index], self.y_data[index])

    def __len__(self):
        return self.len

# %%
train = np.load(DATAPATH+'X_mfcc_001.npy')

# %%
labels = np.load(DATAPATH+'y.npy')

# %%
print('train:', train.shape)
print('labels:', labels.shape)
# Out:
# train: (1532, 60, 35)
# labels: (1532,)

# %%
train_dataset = CattleSoundDataset(train, labels)

# %% [markdown]
# ### STEP 2: MAKING DATASET ITERABLE

# %%
batch_size = 32

# %%
transformations = transforms.Compose([transforms.ToTensor()])

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size= batch_size, 
                                           shuffle=True)

# %% [markdown]
# ### STEP 3: CREATE MODEL CLASS

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=(1,1)),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=(1,1)),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

        self.max_pool = nn.MaxPool2d(2)
        self._init_weights()
        
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.zeros_(m.bias)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.max_pool(x)
        return x

# %%
class CNNModel(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        
        self.conv = nn.Sequential(
            ConvBlock(in_channels=1, out_channels=32),
            ConvBlock(in_channels=32, out_channels=64),
        )
        
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(7680, 1024),
            nn.PReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.1),
            nn.Linear(1024, num_classes),
        )

    def forward(self, x):
        out = self.conv(x)
        out = out.view(out.size(0), -1)
        #x = torch.mean(x, dim=3)
        #x, _ = torch.max(x, dim=2)
        out = self.fc(out)
        return out

# %% [markdown]
# ### STEP 4: LOAD MODEL PRETRAINED

# %%
model = CNNModel(num_classes=3, )

# %%
state = torch.load(MODELPATH+'cnn_pretrained.model')

# %%
model.load_state_dict(state['state_dict'])

# %%
#######################
#  USE GPU FOR MODEL  #
#######################

if torch.cuda.is_available():
    model.cuda()

# %% [markdown]
# ### STEP 5: INSTANTIATE LOSS CLASS

# %%
criterion = nn.CrossEntropyLoss().cuda()

# %% [markdown]
# ### STEP 6: LOAD OPTIMIZER

# %%
learning_rate = 0.001

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
optimizer.load_state_dict(state['optimizer'])

# %%
num_epochs = state['epoch']

# %% [markdown]
# ### STEP 7: TRAIN THE MODEL

# %%
niter = 0
for epoch in range(num_epochs):
    print('Epoch: {}'.format(epoch+1))
    
    for i, (images, labels) in enumerate(Bar(train_loader)):
        

        #######################
        #  USE GPU FOR MODEL  #
        #######################
        if torch.cuda.is_available():
            images = Variable(images.unsqueeze(1).cuda())
            labels = Variable(labels.cuda())
        else:
            images = Variable(images.unsqueeze(1))
            labels = Variable(labels)
        
        # Clear gradients w.r.t. parameters
        optimizer.zero_grad()
        
        # Forward pass to get output/logits
        #images = images.unsqueeze(1).type(torch.FloatTensor).cuda()
        outputs = model(images.to(dtype=torch.float))
        
        # Calculate Loss: softmax --> cross entropy loss
        loss = criterion(outputs, labels)
        
        # Getting gradients w.r.t. parameters
        loss.backward()
        
        # Updating parameters
        optimizer.step()
# Out:
# Epoch: 1
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 2
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 3
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 4
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 5
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 6
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 7
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 8
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 9
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 10
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 11
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 12
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 13
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 14
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 15
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 16
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 17
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 18
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 19
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 20
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 21
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 22
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 23
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 24
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 25
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 26
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 27
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 28
# 1532/1532: [===============================>] - ETA 0.0s
# Epoch: 29
# 1532/1532: [===============================>] - ETA 0.0s

# %% [markdown]
# ### STEP 8: SAVING THE MODEL

# %% [raw]
# torch.save(model, MODELPATH+'cnn_004.model')

# %%
state = {
    'epoch': num_epochs,
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict()
}
torch.save(state, MODELPATH+'cnn_004.model')

# %%
model.state_dict()
# Out:
# OrderedDict([('conv.0.conv1.0.weight',
#               tensor([[[[-3.3157e-01, -7.9121e-01, -5.9977e-01],
#                         [-3.6659e-02, -5.0308e-01, -1.4643e-01]]],
#
#
#                       [[[ 1.2172e-03,  7.6884e-01, -7.8729e-01],
#                         [-8.6485e-01, -2.7277e-01,  4.8543e-01],
#                         [-3.8074e-01, -7.2359e-01,  6.6018e-01]]],
#
#
#                       [[[-5.6433e-01,  5.4774e-01,  3.2428e-01],
#                         [ 5.8020e-01,  4.9448e-02, -2.9658e-01],
#                         [ 8.8890e-01, -1.5331e-01,  8.8959e-02]]],
#
#
#                       [[[ 1.3942e-01, -3.7898e-01,  4.9540e-01],
#                         [-2.4595e-01, -9.7757e-01,  2.0107e-01],
#                         [ 1.3515e-01, -6.0409e-01, -3.5036e-01]]]], device='cuda:0')),
#              ('conv.0.conv1.0.bias',
#               tensor([ 4.0762e-04,  2.2229e-04, -1.0579e-03,  7.8657e-04,  1.7211e-04,
#                        2.8358e-04,  4.5524e-04,  9.7932e-04, -3.2492e-04,  2.6110e-04,
#                        9.8402e-05,  4.4763e-05, -5.5133e-04, -2.9208e-04,  4.4505e-04,
#                       -3.6712e-03,  4.4278e-04, -1.9902e-04, -2.6406e-04,  1.9061e-03,
#                        2.0380e-04,  1.3023e-05,  3.4263e-04, -1.2563e-05, -9.4438e-06,
#                        1.8709e-04,  1.0794e-05,  4.9436e-05, -2.7920e-05,  7.8361e-04,
#                       -4.2559e-04,  6.3771e-06], device='cuda:0')),
#              ('conv.0.conv1.1.weight',
#               tensor([0.9794, 0.9842, 1.0068, 1.0064, 0.9921, 1.0101, 1.0076, 1.0069, 1.0031,
#                       0.9936, 0.9932, 0.9784, 1.0362, 0.9935, 1.0031, 1.0547, 0.9975, 0.9891,
#                       0.9986, 0.9932, 1.0171, 0.9783, 0.9976, 0.9975, 0.9894, 0.9940, 0.9789,
#                       1.0175, 1.0242, 1.0055, 1.0152, 1.0009], device='cuda:0')),
#              ('conv.0.conv1.1.bias',
#               tensor([ 0.0055,  0.0135,  0.0278,  0.0271,  0.0107,  0.0132,  0.0470,  0.0174,
#                       -0.0051,  0.0159,  0.0265, -0.0156,  0.0095, -0.0252,  0.0066,  0.0637,
#                        0.0378,  0.0210,  0.0317,  0.0250,  0.0529,  0.0254,  0.0170, -0.0123,
#                        0.0279, -0.0178, -0.0048, -0.0106,  0.0135, -0.0116,  0.0318,  0.0320],
#                      device='cuda:0')),
#              ('conv.0.conv1.1.running_mean',
#               tensor([ 2.7163e+00,  3.9263e+00, -1.9499e+00, -7.0972e-03,  2.2634e+00,
#                       -3.6231e+00,  4.9008e+00, -9.8507e-01,  7.7085e+00, -5.7408e-02,
#                        2.7805e+00,  2.5727e+00, -2.6876e+00,  1.1225e+00, -3.2735e+00,
#                       -1.6387e+00, -1.4281e+00,  6.2037e-01,  6.2097e-01, -1.5351e+00,
#                       -2.0064e-01,  1.9434e+00, -4.8785e+00,  6.0009e+00,  2.6400e+00,
#                        2.8616e+00,  5.4979e+00, -6.4517e+00, -2.9919e+00, -1.0049e+00,
#                        2.2941e+00, -2.1866e+00], device='cuda:0')),
#              ('conv.0.conv1.1.running_var',
#               tensor([6376.3975, 2566.2556, 8058.9727, 2325.0569,  618.2221, 3480.4446,
#                       7234.2793, 1393.8413, 1526.1145, 5972.7197, 5093.7114, 3325.0811,
#                       1397.8782, 2192.6174, 1782.9528,  301.3849, 2450.7612, 2348.0525,
#                        984.0221,  891.6837, 2239.7939, 5669.3188, 7510.1792, 5605.7969,
#                       7233.0381,  574.8170, 2702.2786, 3099.2729, 2465.5530,  825.9403,
#                        381.3189, 2074.7666], device='cuda:0')),
#              ('conv.0.conv1.1.num_batches_tracked',
#               tensor(3364, device='cuda:0')),
#              ('conv.0.conv2.0.weight', tensor([[[[-0.0243, -0.0290,  0.0780],
#                         [-0.0609, -0.0370,  0.0989],
#                         [ 0.0277, -0.0800,  0.0703]],
#
#                        [[-0.1075, -0.0513,  0.1623],
#                         [ 0.0080, -0.0702,  0.0226],
#                         [-0.0601, -0.1584,  0.0820]],
#
#                        [[-0.2588, -0.0449, -0.0031],
#                         [ 0.0295, -0.0097, -0.0556],
#                         [-0.0568,  0.0607,  0.0073]],
#
#                        ...,
#
#                        [[ 0.1299, -0.0589,  0.0415],
#                         [-0.0821, -0.0686,  0.0822],
#                         [-0.0698, -0.1602,  0.1122]],
#
#                        [[-0.1189,  0.0893,  0.0467],
#                         [ 0.0068, -0.0268, -0.0715],
#                         [-0.0562,  0.0326,  0.1482]],
#
#                        [[ 0.0751,  0.0841,  0.2536],
#                         [ 0.0236,  0.1210, -0.0929],
#                         [-0.0181, -0.0972,  0.1551]]],
#
#
#                       [[[ 0.0292, -0.0960,  0.0057],
#                         [-0.1111,  0.0013, -0.0422],
#                         [ 0.0567, -0.0386,  0.1522]],
#
#                        [[ 0.0411, -0.0427,  0.0620],
#                         [-0.0545, -0.1051,  0.0614],
#                         [ 0.0189,  0.0063,  0.1148]],
#
#                        [[-0.0399, -0.0822, -0.0045],
#                         [ 0.0481,  0.0463, -0.1072],
#                         [ 0.1091,  0.0011, -0.0352]],
#
#                        ...,
#
#                        [[ 0.0024,  0.0425, -0.0369],
#                         [-0.0669, -0.0891,  0.0146],
#                         [ 0.1058,  0.0715, -0.1424]],
#
#                        [[-0.0958, -0.0183,  0.0457],
#                         [ 0.1256,  0.0364,  0.0545],
#                         [ 0.0412,  0.0648,  0.0839]],
#
#                        [[ 0.1073, -0.0258,  0.0977],
#                         [ 0.0369,  0.0245,  0.1389],
#                         [-0.0779, -0.0028, -0.0989]]],
#
#
#                       [[[ 0.0188,  0.0640, -0.0714],
#                         [ 0.0832,  0.1661,  0.0808],
#                         [ 0.0631,  0.0023, -0.1035]],
#
#                        [[-0.0685, -0.1994,  0.0182],
#                         [-0.0241, -0.0922,  0.0442],
#                         [ 0.0717, -0.0544, -0.0513]],
#
#                        [[-0.0347, -0.1115,  0.0085],
#                         [ 0.1141,  0.0738, -0.1323],
#                         [ 0.1192,  0.0442, -0.1187]],
#
#                        ...,
#
#                        [[ 0.0505, -0.0672, -0.1971],
#                         [ 0.0358, -0.0665, -0.0150],
#                         [ 0.1019, -0.0552,  0.0422]],
#
#                        [[ 0.0776, -0.0858, -0.0925],
#                         [ 0.0697,  0.1643,  0.0764],
#                         [ 0.1792,  0.1105, -0.0784]],
#
#                        [[-0.0492,  0.0571,  0.1490],
#                         [-0.0453,  0.1675,  0.0123],
#                         [ 0.0024,  0.0169, -0.0009]]],
#
#
#                       ...,
#
#
#                       [[[ 0.0211,  0.0975, -0.0553],
#                         [-0.0928, -0.0101,  0.0074],
#                         [ 0.0050,  0.1335,  0.2026]],
#
#                        [[ 0.0295, -0.0614,  0.0279],
#                         [-0.0587,  0.0459, -0.0690],
#                         [ 0.0091, -0.0690, -0.0789]],
#
#                        [[ 0.0644, -0.0223,  0.0020],
#                         [-0.0879, -0.0548, -0.1807],
#                         [ 0.1279,  0.0308,  0.0348]],
#
#                        ...,
#
#                        [[ 0.0195,  0.1538,  0.0218],
#                         [ 0.1087,  0.1495,  0.1276],
#                         [ 0.0799, -0.0477,  0.1774]],
#
#                        [[ 0.0673,  0.0198, -0.0778],
#                         [ 0.1186, -0.1173, -0.0483],
#                         [-0.0757,  0.1630, -0.0861]],
#
#                        [[ 0.0099, -0.0817, -0.0910],
#                         [-0.0118, -0.1516, -0.0425],
#                         [ 0.1328, -0.0733,  0.1263]]],
#
#
#                       [[[ 0.0764, -0.0465, -0.0250],
#                         [ 0.0056,  0.0712,  0.0498],
#                         [ 0.0191,  0.1569,  0.1624]],
#
#                        [[-0.0456, -0.1212,  0.0520],
#                         [ 0.0292, -0.0289,  0.0289],
#                         [ 0.0591, -0.0786,  0.0442]],
#
#                        [[ 0.0250, -0.1795, -0.0172],
#                         [-0.0047,  0.1075,  0.0207],
#                         [ 0.1058, -0.0913, -0.0124]],
#
#                        ...,
#
#                        [[ 0.0583, -0.0717, -0.0520],
#                         [-0.1688,  0.0536,  0.0371],
#                         [ 0.1239,  0.1567,  0.1258]],
#
#                        [[-0.0913, -0.0931,  0.0101],
#                         [-0.0011,  0.1513, -0.0428],
#                         [ 0.1004,  0.0397,  0.0472]],
#
#                        [[ 0.0912,  0.0069,  0.0255],
#                         [-0.1308, -0.0309,  0.0967],
#                         [ 0.1256, -0.0435,  0.1446]]],
#
#
#                       [[[ 0.1450, -0.0648,  0.0731],
#                         [ 0.0209,  0.1382, -0.0539],
#                         [ 0.0853, -0.0421, -0.0268]],
#
#                        [[ 0.0279, -0.0737, -0.0137],
#                         [-0.1142,  0.1007,  0.1752],
#                         [-0.1645,  0.0146,  0.1058]],
#
#                        [[ 0.0465,  0.0648, -0.0631],
#                         [-0.0600, -0.0177, -0.0463],
#                         [ 0.1123, -0.0923, -0.1080]],
#
#                        ...,
#
#                        [[ 0.1016,  0.0260,  0.1091],
#                         [-0.0654,  0.0366,  0.0141],
#                         [ 0.0139, -0.0344, -0.0627]],
#
#                        [[-0.0066,  0.1071, -0.0212],
#                         [-0.0300,  0.0904,  0.0271],
#                         [ 0.0916,  0.0304,  0.1710]],
#
#                        [[ 0.1249, -0.0308, -0.1454],
#                         [-0.0738,  0.0037,  0.0457],
#                         [-0.0652, -0.2550,  0.0405]]]], device='cuda:0')),
#              ('conv.0.conv2.0.bias',
#               tensor([ 7.8070e-04,  1.5469e-02, -5.3843e-04,  1.3004e-02,  7.3312e-03,
#                        4.4197e-05, -3.5809e-03, -3.9576e-03,  1.6809e-04,  1.4031e-02,
#                       -7.3174e-04, -9.3161e-03,  8.4503e-03, -7.8873e-05,  2.0102e-03,
#                        9.2251e-03,  5.8718e-03, -1.0053e-02, -5.9893e-03, -6.9006e-03,
#                        3.3950e-03, -5.6007e-03, -1.1983e-03,  1.0222e-02, -1.8440e-02,
#                       -9.8736e-04,  9.0070e-03, -1.1909e-02,  1.0562e-02, -1.2513e-02,
#                        4.1704e-03, -7.2557e-03], device='cuda:0')),
#              ('conv.0.conv2.1.weight',
#               tensor([1.0237, 0.9890, 1.0118, 0.9764, 1.0061, 1.0016, 1.0150, 0.9857, 1.0121,
#                       1.0119, 1.0304, 0.9990, 0.9855, 0.9945, 1.0066, 1.0263, 0.9972, 1.0178,
#                       1.0036, 1.0013, 1.0270, 1.0165, 1.0043, 0.9990, 1.0014, 0.9833, 1.0023,
#                       1.0287, 0.9839, 0.9886, 0.9720, 1.0193], device='cuda:0')),
#              ('conv.0.conv2.1.bias',
#               tensor([ 0.0085, -0.0244, -0.0043,  0.0029, -0.0006, -0.0066,  0.0043,  0.0152,
#                        0.0150,  0.0042,  0.0135, -0.0069, -0.0163, -0.0172, -0.0019,  0.0153,
#                        0.0005,  0.0181, -0.0018, -0.0091,  0.0043,  0.0005, -0.0182,  0.0201,
#                       -0.0201, -0.0060,  0.0042,  0.0154, -0.0196, -0.0086,  0.0041,  0.0065],
#                      device='cuda:0')),
#              ('conv.0.conv2.1.running_mean',
#               tensor([ 0.0449,  0.1434, -0.0830, -0.1818, -0.1145, -0.0245, -0.3833, -0.3502,
#                       -0.5113, -0.0720, -0.3424, -0.0364, -0.1759, -0.1278, -0.2738, -0.3319,
#                        0.1632, -0.2305, -0.3041,  0.2501,  0.0074, -0.1647, -0.1498, -0.0987,
#                        0.0312,  0.6590, -0.0671,  0.0676, -0.1934, -0.3474,  0.4860, -0.3240],
#                      device='cuda:0')),
#              ('conv.0.conv2.1.running_var',
#               tensor([0.2258, 0.3495, 0.9241, 0.8978, 0.6107, 0.4505, 0.7492, 1.9164, 1.3276,
#                       0.5262, 0.4829, 0.2591, 1.7554, 0.2923, 0.4389, 1.1323, 0.5652, 0.5070,
#                       0.8091, 0.5111, 0.1680, 0.2255, 0.8871, 0.3210, 0.1826, 2.4979, 0.4320,
#                       0.2885, 0.8624, 1.1426, 1.4838, 0.9551], device='cuda:0')),
#              ('conv.0.conv2.1.num_batches_tracked',
#               tensor(3364, device='cuda:0')),
#              ('conv.1.conv1.0.weight',
#               tensor([[[[ 1.2819e-03, -3.1289e-02,  1.3489e-01],
#                       1.0087, 1.0205, 1.0260, 0.9890, 0.9913, 0.9884, 1.0128, 1.0295, 0.9808,
#                       1.0438, 1.0101, 0.9999, 0.9918, 0.9872, 0.9961, 1.0068, 0.9945, 0.9992,
#                       0.9895, 1.0253, 0.9798, 0.9704, 1.0337, 1.0024, 1.0077, 0.9894, 1.0023,
#                       0.9793, 0.9950, 0.9903, 1.0239, 1.0287, 0.9989, 1.0209, 1.0214, 0.9710,
#                       1.0316], device='cuda:0')),
#              ('conv.1.conv1.1.bias',
#               tensor([-2.0567e-02,  1.1809e-02,  2.6262e-03,  2.3515e-02,  4.2304e-02,
#                       -7.2741e-03, -3.0533e-02,  1.6004e-02,  5.9373e-03,  9.9485e-03,
#                        1.9992e-03, -1.3553e-03, -2.1764e-03,  6.7021e-03,  2.2787e-02,
#                        9.8528e-03,  1.4872e-02, -1.3406e-02, -1.9341e-02, -3.8532e-03,
#                       -4.1528e-03, -2.2518e-02,  3.9741e-02,  3.6497e-02, -3.1787e-02,
#                       -3.3842e-03,  2.3373e-02,  1.2683e-02,  2.7640e-02,  1.5091e-02,
#                        3.8451e-03,  8.6145e-03, -2.9369e-03,  4.0732e-02,  1.2677e-02,
#                        1.8707e-02, -5.2167e-03, -3.4641e-03, -2.4916e-03, -1.0364e-03,
#                       -2.7000e-02,  9.0029e-03, -5.1099e-03,  3.5254e-05,  1.3221e-02,
#                        2.5286e-03,  7.1450e-03, -2.2891e-02, -2.0848e-02,  1.5586e-02,
#                        3.4068e-02,  4.3413e-04,  1.6210e-02, -1.0297e-02, -1.7787e-02,
#                       -1.5952e-03,  9.2498e-03,  4.2817e-04,  2.0193e-02,  1.3094e-02,
#                        1.7175e-02,  1.4633e-02, -2.6290e-02,  4.3484e-02], device='cuda:0')),
#              ('conv.1.conv1.1.running_mean',
#               tensor([-0.0992,  0.8138, -0.0158, -1.1990,  0.3475, -0.2333, -0.0748, -0.0197,
#                       -0.5835,  0.4469, -0.1270,  0.2649,  0.7234,  0.1917, -0.3646, -0.2904,
#                        0.4012,  0.5148,  0.8908, -0.9484, -0.3686,  0.2425, -0.7428, -0.6273,
#                       -1.1233,  1.1798,  0.0473, -0.6730,  0.3715,  0.5788, -0.1173, -0.0972,
#                        0.1831,  0.3426,  0.2083,  0.7966,  0.2785, -0.0224,  0.2522,  0.0041,
#                        0.4530, -0.1735, -0.2337,  0.3172, -0.7918, -0.5502, -0.7937,  0.3243,
#                        0.9910, -0.1768, -0.0116, -0.3208, -0.8593,  0.4915,  0.2433, -0.3921,
#                        0.2360, -0.6329, -0.2670,  0.4711,  0.0604,  1.3144, -0.1541,  0.2778],
#                      device='cuda:0')),
#              ('conv.1.conv1.1.running_var',
#               tensor([1.2022, 0.3278, 0.2581, 1.0925, 0.5309, 0.4200, 0.5300, 0.5536, 1.2896,
#                       0.5679, 1.5161, 0.6663, 0.6392, 0.5445, 2.0358, 0.4727, 0.2538, 1.0082,
#                       1.0592, 0.5973, 1.5797, 1.1224, 0.7482, 0.8020, 0.9734, 1.2685, 0.4646,
#                       1.0830, 0.4608, 0.6464, 3.3156, 0.4521, 0.3725, 0.2838, 0.3198, 0.2698,
#                       0.3715, 0.4540, 0.8833, 0.3750, 1.8055, 2.2292, 0.9571, 0.7745, 2.6096,
#                       0.8111, 0.9254, 2.3637, 1.5147, 0.5682, 0.5355, 0.3357, 0.8121, 0.7648,
#                       0.6803, 1.1834, 0.4544, 1.1345, 0.1822, 0.3532, 0.4638, 0.3465, 0.6107,
#                       0.2074], device='cuda:0')),
#              ('conv.1.conv1.1.num_batches_tracked',
#               tensor(3364, device='cuda:0')),
#              ('conv.1.conv2.0.weight',
#               tensor([[[[ 1.5158e-01,  3.3713e-02, -1.1752e-02],
#                         [ 1.3281e-02, -2.2172e-03, -1.2278e-01],
#                         [-5.3513e-02,  5.0224e-02, -9.5026e-04]],
#
#                        [[ 5.7962e-02,  1.3183e-02, -3.1916e-02],
#                         [-2.8471e-02,  4.2048e-04, -3.5731e-02],
#                         [ 3.3992e-02,  4.8225e-02, -3.9252e-02]],
#
#                        [[-6.5437e-02, -2.2375e-02, -8.2817e-03],
#                         [-3.9762e-02, -7.6159e-03,  6.8275e-02],
#                         [ 1.1641e-01,  8.7447e-02,  3.7225e-03]],
#
#                        ...,
#
#                        [[ 3.9947e-02, -1.8744e-03, -1.3298e-03],
#                         [-1.0009e-01, -1.1940e-01,  1.2529e-01],
#                         [-7.4105e-03,  7.9119e-02, -8.2479e-03]],
#
#                        [[ 8.1940e-03, -1.0074e-01, -2.0175e-02],
#                         [-3.9231e-02,  1.0973e-01,  6.5452e-04],
#                         [ 3.0976e-02, -5.6348e-03,  2.9814e-02]],
#
#                        [[-8.0048e-03,  4.1645e-02,  2.0909e-02],
#                         [-3.0007e-02, -4.3272e-02,  2.1507e-02],
#                         [-1.2915e-01, -9.0171e-02,  7.6860e-02]]],
#
#
#                       [[[ 1.6349e-02, -1.7027e-02,  3.2881e-03],
#                         [ 5.3782e-02,  9.9639e-02,  7.7444e-02],
#                         [-8.2313e-02, -1.0893e-01, -5.7496e-02]],
#
#                        [[ 2.5245e-02,  6.3715e-02,  6.2146e-02],
#                         [-8.4409e-03, -4.6412e-02,  4.7460e-02],
#                         [-2.0237e-02, -4.8072e-02,  1.6292e-02]],
#
#                        [[ 7.0258e-03,  6.8124e-02, -7.7353e-02],
#                         [-3.8935e-02,  2.8590e-02,  7.5970e-02],
#                         [-5.7986e-02,  3.3465e-02,  9.5328e-03]],
#
#                        ...,
#
#                        [[-5.9084e-02,  3.3544e-02, -2.6921e-02],
#                         [-9.2471e-03, -1.1575e-01, -1.0170e-01],
#                         [-1.9193e-02,  6.4450e-02, -5.5083e-02]],
#
#                        [[ 4.8479e-02, -8.7362e-02,  3.0773e-02],
#                         [-3.6621e-03,  8.8401e-03,  9.6938e-02],
#                         [-9.5391e-02, -6.5936e-03, -1.1990e-02]],
#
#                       -2.0542e-03,  1.3733e-03, -1.7408e-03, -2.3539e-03,  1.9119e-03,
#                        3.5094e-04,  2.6095e-03, -7.6252e-05, -9.8004e-04,  1.2530e-03,
#                       -5.2960e-04, -6.4771e-04, -2.3356e-04,  7.6677e-04,  6.8535e-04,
#                        1.6815e-03,  1.8302e-03, -7.0785e-04,  1.3590e-03,  1.4289e-03,
#                       -1.1835e-04,  6.9612e-05, -6.9697e-03, -1.5969e-03], device='cuda:0')),
#              ('conv.1.conv2.1.weight',
#               tensor([1.0003, 1.0031, 1.0203, 1.0115, 1.0089, 0.9963, 0.9904, 0.9979, 0.9954,
#                       0.9913, 1.0132, 1.0114, 0.9872, 1.0032, 1.0224, 1.0061, 0.9785, 0.9982,
#                       1.0024, 1.0089, 1.0004, 1.0054, 0.9967, 1.0038, 1.0098, 0.9931, 1.0056,
#                       0.9905, 1.0059, 0.9915, 0.9938, 0.9856, 1.0050, 0.9896, 1.0329, 0.9902,
#                       0.9923, 1.0025, 1.0217, 0.9937, 0.9986, 0.9868, 1.0068, 1.0006, 0.9894,
#                       0.9830, 1.0297, 0.9723, 1.0058, 0.9980, 1.0066, 1.0123, 1.0140, 0.9970,
#                       0.9840, 1.0367, 1.0103, 1.0054, 0.9943, 1.0059, 0.9953, 0.9941, 0.9915,
#                       0.9754], device='cuda:0')),
#              ('conv.1.conv2.1.bias',
#               tensor([-0.0159, -0.0197,  0.0031,  0.0077, -0.0327, -0.0422, -0.0203, -0.0075,
#                       -0.0419, -0.0157, -0.0223, -0.0177, -0.0282, -0.0021, -0.0224,  0.0081,
#                       -0.0008,  0.0086, -0.0058, -0.0231, -0.0090, -0.0249, -0.0166, -0.0043,
#                       -0.0009, -0.0169, -0.0279, -0.0120, -0.0130, -0.0155,  0.0040, -0.0172,
#                       -0.0142, -0.0432, -0.0042, -0.0138, -0.0196, -0.0053, -0.0097, -0.0337,
#                       -0.0206, -0.0215, -0.0154, -0.0132, -0.0175, -0.0530, -0.0127, -0.0160,
#                       -0.0136, -0.0290,  0.0016, -0.0125, -0.0009, -0.0227, -0.0250,  0.0120,
#                       -0.0216, -0.0025, -0.0227, -0.0152, -0.0293, -0.0241, -0.0128, -0.0198],
#                      device='cuda:0')),
#              ('conv.1.conv2.1.running_mean',
#               tensor([ 0.1800, -0.1393,  0.1350, -0.8420, -0.0377, -0.7000,  0.4353,  0.1507,
#                        0.1134, -0.1286,  0.2581, -0.2884, -0.7149, -1.3943,  0.1336, -0.0436,
#                       -0.2747, -0.3898,  0.2767, -0.4789, -0.0802,  0.0120, -0.7425,  0.1390,
#                       -0.0236,  0.2366,  0.4160,  0.0709,  0.2196,  0.8034,  0.0929,  0.5593,
#                        0.1096,  0.0586,  0.1626,  0.1643, -0.2419,  0.2460,  0.0054, -0.2447,
#                        0.3355, -0.4260, -0.4085, -0.1116,  1.2162,  0.5689, -0.1927, -0.1241,
#                        0.0997, -0.4749, -0.2773, -0.4362,  0.3688, -0.0400, -0.0561,  0.3920,
#                        0.0306, -0.1342,  0.1985, -0.3668,  0.4220,  0.5339,  0.2889,  0.1865],
#                      device='cuda:0')),
#              ('conv.1.conv2.1.running_var',
#               tensor([0.4488, 0.7349, 0.4285, 0.3840, 0.5366, 0.5337, 0.5059, 0.6726, 0.4352,
#                       0.8676, 0.4891, 0.3932, 0.6212, 2.0601, 0.2306, 0.2599, 0.9988, 0.6032,
#                       0.5846, 0.6536, 0.6593, 0.5993, 0.3740, 0.3266, 0.5279, 0.3918, 0.4126,
#                       0.4526, 0.5722, 0.3975, 0.5236, 0.6103, 0.6219, 0.4324, 0.4254, 0.9645,
#                       0.8513, 0.3263, 0.4199, 0.5900, 0.5254, 0.2492, 0.4979, 0.4226, 0.6441,
#                       0.7883, 0.4917, 1.2359, 0.4453, 0.3736, 0.5483, 0.4948, 0.3842, 0.2859,
#                       1.3668, 0.2941, 0.4872, 0.8420, 0.4648, 0.7692, 0.9747, 0.7322, 0.4282,
#                       0.4441], device='cuda:0')),
#              ('conv.1.conv2.1.num_batches_tracked',
#               tensor(3364, device='cuda:0')),
#              ('fc.1.weight',
#               tensor([[ 0.0105,  0.0053,  0.0016,  ..., -0.0181,  0.0086,  0.0309],
#                       [-0.0013,  0.0033, -0.0030,  ...,  0.0025,  0.0018, -0.0379],
#                       [-0.0040, -0.0035,  0.0058,  ...,  0.0012, -0.0021,  0.0010],
#                       ...,
#                       [-0.0007,  0.0022,  0.0106,  ..., -0.0026,  0.0109,  0.0014],
#                       [ 0.0065,  0.0025, -0.0008,  ..., -0.0158, -0.0020, -0.0251],
#                       [ 0.0160,  0.0094, -0.0061,  ...,  0.0064,  0.0111, -0.0210]],
#                      device='cuda:0')),
#              ('fc.1.bias',
#               tensor([-0.0035, -0.0048,  0.0088,  ..., -0.0182,  0.0215,  0.0094],
#                      device='cuda:0')),
#              ('fc.2.weight', tensor([0.1725], device='cuda:0')),
#              ('fc.3.weight',
#               tensor([0.7723, 0.9612, 0.2074,  ..., 0.0666, 0.3375, 0.8905], device='cuda:0')),
#              ('fc.3.bias',
#               tensor([-0.0596, -0.0287, -0.0683,  ..., -0.0696, -0.0542,  0.0482],
#                      device='cuda:0')),
#              ('fc.3.running_mean',
#               tensor([-2.8157,  1.4784,  1.8048,  ...,  6.7001, 12.4799,  6.6459],
#                      device='cuda:0')),
#              ('fc.3.running_var',
#               tensor([ 0.1790,  4.7367,  5.0313,  ..., 14.5843,  4.5907,  5.1404],
#                      device='cuda:0')),
#              ('fc.3.num_batches_tracked', tensor(3364, device='cuda:0')),
#              ('fc.5.weight',
#               tensor([[ 0.0137, -0.0048,  0.0216,  ...,  0.0252, -0.0084,  0.0197],
#                       [-0.0075, -0.0129, -0.0339,  ..., -0.0553, -0.0261,  0.0263],
#                       [-0.0028,  0.0120,  0.0246,  ...,  0.0269, -0.0050,  0.0258]],
#                      device='cuda:0')),
#              ('fc.5.bias',
#               tensor([-0.0859,  0.0607, -0.0229], device='cuda:0'))])
